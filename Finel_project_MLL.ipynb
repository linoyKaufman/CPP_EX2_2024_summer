# %% [markdown]
# <a href="https://colab.research.google.com/github/linoyKaufman/CPP_EX2_2024_summer/blob/main/Finel_project_MLL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q sentence-transformers pandas

# %%
from sentence_transformers import SentenceTransformer
import pandas as pd
# Out:
# WARNING:torchao.kernel.intmm:Warning: Detected no triton, on systems without Triton certain kernels will not work

# %%
len(dreams)
# Out:
# 5

# %%
# Load embedding model
model = SentenceTransformer("sentence-transformers/all-MiniLM-L6-v2")

# Create embeddings for the toy dreams
embeddings = model.encode(dreams, show_progress_bar=True)

print("Embeddings shape:", embeddings.shape)
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Embeddings shape: (5, 384)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# We will use pandas to read the CSV file. Assuming the dreams are in the first column, we convert it to a list.
dreams_df = pd.read_csv('/content/all_dreams_combined.csv')
dreams = dreams_df.iloc[:, 0].tolist()

len(dreams)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3520858406.py in <cell line: 0>()
#       1 # We will use pandas to read the CSV file. Assuming the dreams are in the first column, we convert it to a list.
# ----> 2 dreams_df = pd.read_csv('/content/all_dreams_combined.csv')
#       3 dreams = dreams_df.iloc[:, 0].tolist()
#       4
#       5 len(dreams)
#
# ...
